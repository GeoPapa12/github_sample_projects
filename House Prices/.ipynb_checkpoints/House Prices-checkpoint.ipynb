# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.datasets import load_boston
import matplotlib.pyplot as plt
import seaborn as sns
import sys
import math

sys.path.append("..")

from EDA_ML_Functions.ML_functions import ML_models
from EDA_ML_Functions.NN_functions import ANN_tabular_class


pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 15)
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\numpy\_distributor_init.py:32: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\user\Anaconda3\lib\site-packages\numpy\.libs\libopenblas.NOIJJG62EMASZI6NYURL6JBKM4EVBGM7.gfortran-win_amd64.dll
# C:\Users\user\Anaconda3\lib\site-packages\numpy\.libs\libopenblas.QVLO2T66WEPI7JZ63PS3HMOHFEY472BC.gfortran-win_amd64.dll
# C:\Users\user\Anaconda3\lib\site-packages\numpy\.libs\libopenblas.WCDJNK7YVMPZQ2ME2ZZHJJRJ3JIKNDB7.gfortran-win_amd64.dll
#   stacklevel=1)
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-f5b86ff0c23f> in <module>
#      10 sys.path.append("..")
#      11
# ---> 12 from EDA_ML_Functions.ML_functions import ML_models
#      13 from EDA_ML_Functions.NN_functions import ANN_tabular_class
#      14
#
# ModuleNotFoundError: No module named 'EDA_ML_Functions'

# %%
# ------------------- Importing Data and classes ------------------------------

ML = ML_models()
ΝΝ = ANN_tabular_class()

df = pd.read_csv('kc_house_data.csv')
# Out:
# --------------------------------------------------------------

# %%
def descriptive_analysis(data, target_attribute='none'):
    """ A table is created with the characteristics of a dataframe
    The table is printed in the pdf report

    Parameters
    ----------
    df: (dataframe)
    target_attribute: (str) optional

    Output: table
    """
    
    # 1. Print describe()
    print(data.describe())
    
    df = round(data.copy(deep=True), 2)

    # 2. Print df size
    print('\nnumber of attributes: ', len(df.columns), '/ number of instances: ', len(df), '\n')

    # tc: table characteristics
    tc = pd.DataFrame(df.isnull().sum(), columns=['NaN'])
    tc['Unique'] = [len(df[i].unique()) for i in list(df.columns)]
    tc['type'] = df.dtypes

    indexValue = 3
    tc['values'] = [df[clm].unique().tolist()[:indexValue] for clm in list(df.columns)]

    # for i, vl_list in enumerate(df.values):
    #    sm['values'].iloc[i] = [round(vl, 3) for vl in vl_list]

    for x, vl in enumerate(tc['values']):
        if tc['Unique'].iloc[x] > 3:
            vl.append('...')
        for i, y in enumerate(vl):
            if len(str(y)) > 10:
                try:
                    vl[i] = y[:10] + '..'
                except Exception:
                    pass
    tc = tc.reset_index()
    tc = tc.astype(str)

    # 3. print table characteristics
    print(tc)

    if target_attribute != 'none':
        attribute_range(df, target_attribute)

# %%
# ------------------- Data Cleansing ------------------------------

df = df.drop('id', axis=1)
df = df.drop('date', axis=1)
df = df.drop('zipcode', axis=1)
descriptive_analysis(df)

X = df.drop(['price'], 1)
y = df['price']
# Out:
#               price      bedrooms     bathrooms   sqft_living      sqft_lot  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  2.161300e+04
# mean   5.400881e+05      3.370842      2.114757   2079.899736  1.510697e+04
# std    3.671272e+05      0.930062      0.770163    918.440897  4.142051e+04
# min    7.500000e+04      0.000000      0.000000    290.000000  5.200000e+02
# 25%    3.219500e+05      3.000000      1.750000   1427.000000  5.040000e+03
# 50%    4.500000e+05      3.000000      2.250000   1910.000000  7.618000e+03
# 75%    6.450000e+05      4.000000      2.500000   2550.000000  1.068800e+04
# max    7.700000e+06     33.000000      8.000000  13540.000000  1.651359e+06
#
#              floors    waterfront  ...  sqft_basement      yr_built  \
# count  21613.000000  21613.000000  ...   21613.000000  21613.000000
# mean       1.494309      0.007542  ...     291.509045   1971.005136
# std        0.539989      0.086517  ...     442.575043     29.373411
# min        1.000000      0.000000  ...       0.000000   1900.000000
# 25%        1.000000      0.000000  ...       0.000000   1951.000000
# 50%        1.500000      0.000000  ...       0.000000   1975.000000
# 75%        2.000000      0.000000  ...     560.000000   1997.000000
# max        3.500000      1.000000  ...    4820.000000   2015.000000
#
#        yr_renovated           lat          long  sqft_living15     sqft_lot15
# count  21613.000000  21613.000000  21613.000000   21613.000000   21613.000000
# mean      84.402258     47.560053   -122.213896    1986.552492   12768.455652
# std      401.679240      0.138564      0.140828     685.391304   27304.179631
# min        0.000000     47.155900   -122.519000     399.000000     651.000000
# 25%        0.000000     47.471000   -122.328000    1490.000000    5100.000000
# 50%        0.000000     47.571800   -122.230000    1840.000000    7620.000000
# 75%        0.000000     47.678000   -122.125000    2360.000000   10083.000000
# max     2015.000000     47.777600   -121.315000    6210.000000  871200.000000
#
# [8 rows x 18 columns]
#
# number of attributes:  18 / number of instances:  21613
#
#             index NaN Unique     type                                 values
# 0           price   0   4028  float64  [221900.0, 538000.0, 180000.0, '...']
# 1        bedrooms   0     13    int64                       [3, 2, 4, '...']
# 2       bathrooms   0     30  float64                [1.0, 2.25, 3.0, '...']
# 3     sqft_living   0   1038    int64               [1180, 2570, 770, '...']
# 4        sqft_lot   0   9782    int64             [5650, 7242, 10000, '...']
# 5          floors   0      6  float64                 [1.0, 2.0, 1.5, '...']
# 6      waterfront   0      2    int64                                 [0, 1]
# 7            view   0      5    int64                       [0, 3, 4, '...']
# 8       condition   0      5    int64                       [3, 5, 4, '...']
# 9           grade   0     12    int64                       [7, 6, 8, '...']
# 10     sqft_above   2    947  float64         [1180.0, 2170.0, 770.0, '...']
# 11  sqft_basement   0    306    int64                   [0, 400, 910, '...']
# 12       yr_built   0    116    int64              [1955, 1951, 1933, '...']
# 13   yr_renovated   0     70    int64                 [0, 1991, 2002, '...']
# 14            lat   0     62  float64           [47.51, 47.72, 47.74, '...']
# 15           long   0     93  float64     [-122.26, -122.32, -122.23, '...']
# 16  sqft_living15   0    777    int64              [1340, 1690, 2720, '...']
# 17     sqft_lot15   0   8689    int64              [5650, 7639, 8062, '...']

# %%
def nan_heatmap(data):
    """ Creates a bar plot that compares 2 attributes, eg a random att vs
    the target attribute

    Parameters
    ----------
    df: (dataframe)

    Output:
    """
    fig, axes = plt.subplots(figsize=(10, 8))
    clmns = data.columns.tolist()
    if len(clmns) > 10:
        clmns1 = clmns[0:round(len(clmns)/2)]
        nht1 = sns.heatmap(data[clmns1].isnull(), cmap="viridis", yticklabels=False, cbar=False)
        plt.show()
        nht1.set_xticklabels(nht1.get_xmajorticklabels(), fontsize=18)
        figure = nht1.get_figure()

        fig, axes = plt.subplots(figsize=(10, 8))
        clmns2 = clmns[round(len(clmns)/2):-1]
        nht2 = sns.heatmap(data[clmns2].isnull(), cmap="viridis", yticklabels=False, cbar=False)
        plt.show()
        nht2.set_xticklabels(nht2.get_xmajorticklabels(), fontsize=18)
        figure = nht2.get_figure()
    else:
        nht = sns.heatmap(data[clmns].isnull(), cmap="viridis", yticklabels=False, cbar=False, )
        plt.show()
        nht.set_xticklabels(nht.get_xmajorticklabels(), fontsize=18)
        figure = nht.get_figure()

# %%
nan_heatmap(df)

# %%
def heatmap_corr_plot(data, listColmRemove=[]):

    data_columns = data.columns.tolist()

    if listColmRemove != []:
        for colm in listColmRemove:
            data_columns.remove(colm)

    data = data[data_columns]

    mask = np.triu(data.corr())
    plt.figure(figsize=(15, 6))
    sns.heatmap(round(data.corr(), 2), annot=True, fmt='.2g', vmin=-1, vmax=1, center=0, cmap='coolwarm', mask=mask)
    # plt.ylim(18, 0)
    plt.title('Correlation Matrix Heatmap')
    plt.show()

# %%
heatmap_corr_plot(df)

# %%
def bar_hist_EDA_plots(df, plot_type='boxplot', no_rows=0):
    if no_rows == 0:
        no_rows = divmod(len(df.columns), 10)[0]
    fig = plt.figure(figsize=(25, 5*no_rows))
    for i, col in enumerate(df.columns, 1):
        if(df[col].dtype == np.float64 or df[col].dtype == np.int64):

            plt.subplot(no_rows, math.ceil(len(df.columns)/no_rows), i)
            if plot_type == 'boxplot':
                plt.boxplot(df[~df[col].isnull()][col])
                ax = plt.gca()
                ax.axes.xaxis.set_ticklabels([])
            else:
                plt.hist(df[~df[col].isnull()][col])

            plt.title(col, fontsize=20)
        else:
            plt.subplot(no_rows, math.ceil(len(df.columns)/no_rows), i)
            if len(df[col].unique()) <= 5:
                sp = sns.countplot(x=col, data=df)
                plt.setp(sp.get_xticklabels(), ha="right", rotation=25, fontsize=8)
                sp.set(xlabel=None)
            else:
                ax = plt.gca()
                ax.axes.xaxis.set_ticklabels([])
            plt.title(col, fontsize=20)
    plt.tight_layout(pad=0.4, w_pad=0.5, h_pad=5.0)
    plt.show()
    # return fig

# %%
bar_hist_EDA_plots(df, no_rows=2)

# %%
bar_hist_EDA_plots(df, 'hist', no_rows=2)

# %%
sns.jointplot(df.sqft_living, df.price, alpha=0.5)

# %%
from scipy.stats.mstats import winsorize

def outlier_winsorize(data, list_exclude=[]):
    for col in data.columns:
        if col not in list_exclude:
            try:

                # q75, q25 = np.percentile(data[col], [75, 25])
                q75, q25 = np.percentile(data[~data[col].isnull()][col], [75, 25])
                # q95, q05 = np.percentile(data[col], [95, 5])
                iqr = q75 - q25
                min_val = q25 - (iqr*1.5)
                max_val = q75 + (iqr*1.5)

                outlier_count_lower = len(np.where((data[col] < min_val))[0])
                outlier_count_upper = len(np.where((data[col] > max_val))[0])
                outlier_percent_lower = round(outlier_count_lower/len(data[col])*100, 2)
                outlier_percent_upper = round(outlier_count_upper/len(data[col])*100, 2)
                print(15*'-' + col + 15*'-')
                print('Number of outliers lower: {}'.format(outlier_count_lower))
                print('Number of outliers upper: {}'.format(outlier_count_upper))
                print('Percent of data that is outlier lower: {}%'.format(outlier_percent_lower))
                print('Percent of data that is outlier upper: {}%'.format(outlier_percent_upper))

                wins_data = winsorize(data[col], limits=(outlier_percent_lower/100, outlier_percent_upper/100))
                data[col] = wins_data
            except Exception:
                pass
    return data

# %%
df = outlier_winsorize(df, list_exclude=['long', 'lat', 'zipcode', 'yr_renovated', 'yr_built'])
# Out:
# ---------------price---------------
# Number of outliers lower: 0
# Number of outliers upper: 1146
# Percent of data that is outlier lower: 0.0%
# Percent of data that is outlier upper: 5.3%
# ---------------bedrooms---------------
# Number of outliers lower: 212
# Number of outliers upper: 334
# Percent of data that is outlier lower: 0.98%
# Percent of data that is outlier upper: 1.55%
# ---------------bathrooms---------------
# Number of outliers lower: 14
# Number of outliers upper: 557
# Percent of data that is outlier lower: 0.06%
# Percent of data that is outlier upper: 2.58%
# ---------------sqft_living---------------
# Number of outliers lower: 0
# Number of outliers upper: 572
# Percent of data that is outlier lower: 0.0%
# Percent of data that is outlier upper: 2.65%
# ---------------sqft_lot---------------
# Number of outliers lower: 0
# Number of outliers upper: 2425
# Percent of data that is outlier lower: 0.0%
# Percent of data that is outlier upper: 11.22%
# ---------------floors---------------
# Number of outliers lower: 0
# Number of outliers upper: 0
# Percent of data that is outlier lower: 0.0%
# Percent of data that is outlier upper: 0.0%
# ---------------waterfront---------------
# Number of outliers lower: 0
# Number of outliers upper: 163
# Percent of data that is outlier lower: 0.0%
# Percent of data that is outlier upper: 0.75%
# ---------------view---------------
# Number of outliers lower: 0
# Number of outliers upper: 2124
# Percent of data that is outlier lower: 0.0%
# Percent of data that is outlier upper: 9.83%
# ---------------condition---------------
# Number of outliers lower: 30
# Number of outliers upper: 0
# Percent of data that is outlier lower: 0.14%
# Percent of data that is outlier upper: 0.0%
# ---------------grade---------------
# Number of outliers lower: 275
# Number of outliers upper: 1636
# Percent of data that is outlier lower: 1.27%
# Percent of data that is outlier upper: 7.57%
# ---------------sqft_above---------------
# Number of outliers lower: 0
# Number of outliers upper: 611
# Percent of data that is outlier lower: 0.0%
# Percent of data that is outlier upper: 2.83%
# ---------------sqft_basement---------------
# Number of outliers lower: 0
# Number of outliers upper: 496
# Percent of data that is outlier lower: 0.0%
# Percent of data that is outlier upper: 2.29%
# ---------------sqft_living15---------------
# Number of outliers lower: 0
# Number of outliers upper: 544
# Percent of data that is outlier lower: 0.0%
# Percent of data that is outlier upper: 2.52%
# ---------------sqft_lot15---------------
# Number of outliers lower: 0
# Number of outliers upper: 2194
# Percent of data that is outlier lower: 0.0%
# Percent of data that is outlier upper: 10.15%

# %%
plt.figure(figsize=(8, 8))
sns.jointplot(df.sqft_living, df.price, alpha=0.5)
plt.xlabel('Sqft Living')
plt.ylabel('Sale Price')
plt.show()

# %%
non_top_1_perc = df.sort_values('price', ascending=False).iloc[int(len(df)*0.01):]
plt.figure(figsize=(12, 8))
sns.scatterplot(x='long', y='lat',
                data=non_top_1_perc, hue='price',
                palette='RdYlGn', edgecolor=None, alpha=0.2)
# Out:
# <AxesSubplot:xlabel='long', ylabel='lat'>

# %%
bath = ['bathrooms', 'bedrooms']
cm = sns.light_palette("green", as_cmap=True)
pd.crosstab(df[bath[0]], df[bath[1]]).style.background_gradient(cmap=cm)
# Out:
# <style  type="text/css" >
# #T_25811_row0_col0{
#             background-color:  #d8ead8;
#             color:  #000000;
#         }#T_25811_row0_col1,#T_25811_row0_col2,#T_25811_row0_col3,#T_25811_row0_col4,#T_25811_row1_col3,#T_25811_row1_col4,#T_25811_row3_col1,#T_25811_row3_col2,#T_25811_row3_col3,#T_25811_row3_col4,#T_25811_row9_col0,#T_25811_row10_col0,#T_25811_row11_col0,#T_25811_row12_col0,#T_25811_row12_col1{
#             background-color:  #ebf3eb;
#             color:  #000000;
#         }#T_25811_row1_col0{
#             background-color:  #bcdcbc;
#             color:  #000000;
#         }#T_25811_row1_col1{
#             background-color:  #e7f1e7;
#             color:  #000000;
#         }#T_25811_row1_col2,#T_25811_row10_col1,#T_25811_row11_col1{
#             background-color:  #eaf2ea;
#             color:  #000000;
#         }#T_25811_row2_col0,#T_25811_row2_col1,#T_25811_row8_col2,#T_25811_row8_col3,#T_25811_row12_col4{
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }#T_25811_row2_col2{
#             background-color:  #399c39;
#             color:  #000000;
#         }#T_25811_row2_col3,#T_25811_row10_col3{
#             background-color:  #cce4cc;
#             color:  #000000;
#         }#T_25811_row2_col4{
#             background-color:  #d3e7d3;
#             color:  #000000;
#         }#T_25811_row3_col0,#T_25811_row9_col1{
#             background-color:  #e8f2e8;
#             color:  #000000;
#         }#T_25811_row4_col0{
#             background-color:  #d5e9d5;
#             color:  #000000;
#         }#T_25811_row4_col1{
#             background-color:  #beddbe;
#             color:  #000000;
#         }#T_25811_row4_col2{
#             background-color:  #98ca98;
#             color:  #000000;
#         }#T_25811_row4_col3,#T_25811_row11_col3{
#             background-color:  #d4e8d4;
#             color:  #000000;
#         }#T_25811_row4_col4,#T_25811_row9_col2{
#             background-color:  #d0e6d0;
#             color:  #000000;
#         }#T_25811_row5_col0,#T_25811_row7_col0{
#             background-color:  #e4f0e4;
#             color:  #000000;
#         }#T_25811_row5_col1{
#             background-color:  #bdddbd;
#             color:  #000000;
#         }#T_25811_row5_col2{
#             background-color:  #309730;
#             color:  #000000;
#         }#T_25811_row5_col3{
#             background-color:  #a7d2a7;
#             color:  #000000;
#         }#T_25811_row5_col4{
#             background-color:  #a1cfa1;
#             color:  #000000;
#         }#T_25811_row6_col0{
#             background-color:  #e0eee0;
#             color:  #000000;
#         }#T_25811_row6_col1{
#             background-color:  #cae3ca;
#             color:  #000000;
#         }#T_25811_row6_col2{
#             background-color:  #83c083;
#             color:  #000000;
#         }#T_25811_row6_col3{
#             background-color:  #badbba;
#             color:  #000000;
#         }#T_25811_row6_col4,#T_25811_row7_col3{
#             background-color:  #a8d2a8;
#             color:  #000000;
#         }#T_25811_row7_col1,#T_25811_row11_col2,#T_25811_row12_col2{
#             background-color:  #d9ead9;
#             color:  #000000;
#         }#T_25811_row7_col2{
#             background-color:  #7fbe7f;
#             color:  #000000;
#         }#T_25811_row7_col4{
#             background-color:  #a9d3a9;
#             color:  #000000;
#         }#T_25811_row8_col0{
#             background-color:  #e2efe2;
#             color:  #000000;
#         }#T_25811_row8_col1{
#             background-color:  #cde5cd;
#             color:  #000000;
#         }#T_25811_row8_col4{
#             background-color:  #4ea64e;
#             color:  #000000;
#         }#T_25811_row9_col3{
#             background-color:  #afd6af;
#             color:  #000000;
#         }#T_25811_row9_col4{
#             background-color:  #6fb76f;
#             color:  #000000;
#         }#T_25811_row10_col2{
#             background-color:  #d7e9d7;
#             color:  #000000;
#         }#T_25811_row10_col4{
#             background-color:  #81bf81;
#             color:  #000000;
#         }#T_25811_row11_col4{
#             background-color:  #a5d1a5;
#             color:  #000000;
#         }#T_25811_row12_col3{
#             background-color:  #b0d6b0;
#             color:  #000000;
#         }</style><table id="T_25811_" ><thead>    <tr>        <th class="index_name level0" >bedrooms</th>        <th class="col_heading level0 col0" >1</th>        <th class="col_heading level0 col1" >2</th>        <th class="col_heading level0 col2" >3</th>        <th class="col_heading level0 col3" >4</th>        <th class="col_heading level0 col4" >5</th>    </tr>    <tr>        <th class="index_name level0" >bathrooms</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_25811_level0_row0" class="row_heading level0 row0" >0.5</th>
#                         <td id="T_25811_row0_col0" class="data row0 col0" >11</td>
#                         <td id="T_25811_row0_col1" class="data row0 col1" >2</td>
#                         <td id="T_25811_row0_col2" class="data row0 col2" >0</td>
#                         <td id="T_25811_row0_col3" class="data row0 col3" >1</td>
#                         <td id="T_25811_row0_col4" class="data row0 col4" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_25811_level0_row1" class="row_heading level0 row1" >0.75</th>
#                         <td id="T_25811_row1_col0" class="data row1 col0" >28</td>
#                         <td id="T_25811_row1_col1" class="data row1 col1" >26</td>
#                         <td id="T_25811_row1_col2" class="data row1 col2" >16</td>
#                         <td id="T_25811_row1_col3" class="data row1 col3" >2</td>
#                         <td id="T_25811_row1_col4" class="data row1 col4" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_25811_level0_row2" class="row_heading level0 row2" >1.0</th>
#                         <td id="T_25811_row2_col0" class="data row2 col0" >139</td>
#                         <td id="T_25811_row2_col1" class="data row2 col1" >1558</td>
#                         <td id="T_25811_row2_col2" class="data row2 col2" >1780</td>
#                         <td id="T_25811_row2_col3" class="data row2 col3" >325</td>
#                         <td id="T_25811_row2_col4" class="data row2 col4" >50</td>
#             </tr>
#             <tr>
#                         <th id="T_25811_level0_row3" class="row_heading level0 row3" >1.25</th>
#                         <td id="T_25811_row3_col0" class="data row3 col0" >2</td>
#                         <td id="T_25811_row3_col1" class="data row3 col1" >3</td>
#                         <td id="T_25811_row3_col2" class="data row3 col2" >4</td>
#                         <td id="T_25811_row3_col3" class="data row3 col3" >0</td>
#                         <td id="T_25811_row3_col4" class="data row3 col4" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_25811_level0_row4" class="row_heading level0 row4" >1.5</th>
#                         <td id="T_25811_row4_col0" class="data row4 col0" >13</td>
#                         <td id="T_25811_row4_col1" class="data row4 col1" >294</td>
#                         <td id="T_25811_row4_col2" class="data row4 col2" >829</td>
#                         <td id="T_25811_row4_col3" class="data row4 col3" >254</td>
#                         <td id="T_25811_row4_col4" class="data row4 col4" >56</td>
#             </tr>
#             <tr>
#                         <th id="T_25811_level0_row5" class="row_heading level0 row5" >1.75</th>
#                         <td id="T_25811_row5_col0" class="data row5 col0" >4</td>
#                         <td id="T_25811_row5_col1" class="data row5 col1" >304</td>
#                         <td id="T_25811_row5_col2" class="data row5 col2" >1870</td>
#                         <td id="T_25811_row5_col3" class="data row5 col3" >719</td>

# %%
# ------------------- ML Analysis ------------------------------
X = df.drop(['price'], 1)
y = df['price']

# %%
results_NN = ΝΝ.create_and_fit_model(X, y, batch_size=10, epochs=400, lyrs=[19, 19, 19, 19], dr=0, NNtype='Regression')
# Out:
#  ================ NN Analysis Completed ================
#   model        mae        rmse     r2 dtype            layers   opt  dr
# 0    NN  89763.481  120624.258  0.763  test  [19, 19, 19, 19]  Adam   0

# %%
resultsML = ML.ML_Basic_Models_Regression(X, y)
# Out:
# [00:33:18] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:33:19] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:33:20] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:33:22] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:33:23] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:33:24] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
#  ================ ML Analysis Completed ================
#     model         mae        rmse     r2 dtype           mse  fit_tm  \
# 1      RF   56796.113   83076.804  0.892  test           NaN     NaN
# 4      BR   60441.818   88153.438  0.878  test           NaN     NaN
# 6    XGBR   64784.582   90858.476  0.870  test           NaN     NaN
# 0    LReg   99054.267  129569.058  0.737  test           NaN     NaN
# 2   Ridge   99095.965  129594.133  0.736  test           NaN     NaN
# 5      BR   99072.327  129579.704  0.736  test           NaN     NaN
# 3   Lasso  105667.545  137969.287  0.701  test           NaN     NaN
# 8      RF   57791.872   85351.302  0.883    cv  7.289143e+09   9.137
# 11     BR   61084.518   89468.819  0.871    cv  8.010576e+09   1.015
# 13   XGBR   64664.475   90870.510  0.867    cv  8.260990e+09   1.292
# 7    LReg   98285.030  129261.200  0.731    cv  1.670975e+10   0.014
# 9   Ridge   98298.598  129262.512  0.731    cv  1.671007e+10   0.008
# 12     BR   98290.636  129260.728  0.731    cv  1.670962e+10   0.020
# 10  Lasso  107034.489  139338.223  0.688    cv  1.941597e+10   0.018
#
#     score_tm  mae%erroor  rmse%erroor
# 1        NaN       0.111        0.162
# 4        NaN       0.118        0.172
# 6        NaN       0.127        0.178
# 0        NaN       0.194        0.253
# 2        NaN       0.194        0.253
# 5        NaN       0.194        0.253
# 3        NaN       0.207        0.270
# 8      0.085       0.113        0.167
# 11     0.014       0.119        0.175
# 13     0.011       0.126        0.178
# 7      0.002       0.192        0.253
# 9      0.002       0.192        0.253
# 12     0.002       0.192        0.253
# 10     0.002       0.209        0.272
